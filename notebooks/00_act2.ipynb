# %%
# Installation directe depuis GitHub
# (Cela télécharge et installe GeoTessera automatiquement)
# !pip install git+https://github.com/ucam-eo/geotessera.git
# Out:
# ^C
# ...
#   Cloning https://github.com/ucam-eo/geotessera.git to c:\users\valen\appdata\local\temp\pip-req-build-lnd70cvv
#   Resolved https://github.com/ucam-eo/geotessera.git to commit 79651c342a30ee60af5e76a46358cbaf56844772
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/ucam-eo/geotessera.git 'C:\Users\valen\AppData\Local\Temp\pip-req-build-lnd70cvv'
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\valen\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import geopandas as gpd
from geotessera import GeoTessera
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================
# 1. DÉFINITION DE LA ZONE (Abadam)
# ==============================================================================
print("Chargement de la zone d'intérêt...")
gdf = gpd.read_file("../Dataset creation - NASA Nigeria/gadm41_NGA_2.json")
abadam = gdf[gdf['NAME_2'] == 'Abadam']

# On récupère la Bounding Box (min_x, min_y, max_x, max_y)
bbox = abadam.total_bounds
print(f"Bbox Abadam : {bbox}")
# Format GeoTessera : "min_lon,min_lat,max_lon,max_lat"
str_bbox = f"{bbox[0]},{bbox[1]},{bbox[2]},{bbox[3]}"

) as src:
                plt.figure(figsize=(10, 10))
                show(src, title="TESSERA Embeddings - Abadam (Dimensions 1-3)")
                plt.axis('off')
                plt.show()
                print("L'image ci-dessus représente la 'vision' du modèle IA sur le terrain.")

    except Exception as e:
        print(f"❌ Une erreur est survenue pendant l'export : {e}")
# Out:
# Chargement de la zone d'intérêt...
# Bbox Abadam : [12.8152 13.0734 13.4861 13.7144]
