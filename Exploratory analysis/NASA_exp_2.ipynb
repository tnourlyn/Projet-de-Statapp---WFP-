# %%
import pandas as pd

# %%
data = pd.read_csv("../NIGERIA_WFP_ADMIN1.csv")

# %% [markdown]
# #Definition of lean seasons :
# Lean seasons are defined as the seasons furthest from harvest meaning they can be defined by the months during which there are no harvests or when food is least accessible : to farmers when SPI is highest or to the people when food prices are high
