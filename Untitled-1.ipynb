# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("NIGERIA_WFP_ADMIN1.csv", sep=None, engine="python")
df["time"] = pd.to_datetime(df["time"], errors="coerce", dayfirst=True)
df = df.dropna(subset=["time", "NAME_1"])
df["year"] = df["time"].dt.year

# NDVI: prends celui que tu as (vim)
df["ndvi"] = df["vim"]

# On filtre la qualité NDVI
df = df[df["viq"] >= 80].copy()   

df = df.sort_values(["NAME_1", "time"])
print(df.head(5))
# Out:
#           time NAME_1  inadequate  bnds      Y         X  Evap_tavg  \
# 0   2023-01-01   Abia    0.296774   0.5  5.395  7.471889   0.000016
# 28  2023-01-02   Abia    0.401515   0.5  5.395  7.471889   0.000014
# 56  2023-01-03   Abia    0.281046   0.5  5.395  7.471889   0.000026
# 84  2023-01-04   Abia    0.300613   0.5  5.395  7.471889   0.000030
# 112 2023-01-05   Abia    0.226667   0.5  5.395  7.471889   0.000039
#
#      LWdown_f_tavg  Lwnet_tavg  Psurf_f_tavg  ...  SoilMoi40_100cm_tavg  \
# 0       385.566324  -71.064699  99941.271400  ...              0.374807
# 28      392.934595  -69.757725  99864.297600  ...              0.365446
# 56      408.719824  -44.999965  99913.329933  ...              0.379434
# 84      416.609924  -39.776577  99798.052400  ...              0.396723
# 112     419.145751  -35.249339  99990.250067  ...              0.413261
#
#      SoilMoi100_200cm_tavg  SoilTemp00_10cm_tavg  SoilTemp10_40cm_tavg  \
# 0                 0.389133            300.138219            299.605325
# 28                0.375858            301.087698            300.549694
# 56                0.378395            299.624543            299.767199
# 84                0.403678            299.950588            299.849166
# 112               0.422155            299.604193            299.639713
#
#      SoilTemp40_100cm_tavg  SoilTemp100_200cm_tavg       vim         viq  \
# 0               299.121555              298.700373  0.569790  101.510920
# 28              300.019129              299.368246  0.598635  100.312830
# 56              299.874593              299.740318  0.683211  102.223080
# 84              299.700418              299.525405  0.751135  102.335600
# 112             299.624382              299.501924  0.790905  102.097565
#
#      year      ndvi
# 0    2023  0.569790
# 28   2023  0.598635
# 56   2023  0.683211
# 84   2023  0.751135
# 112  2023  0.790905
#
# [5 rows x 33 columns]

# %%
def phenology_one_year(g, consec=1, q_base=0.10, frac_amp=0.15):
    g = g.sort_values("time").dropna(subset=["ndvi"])
    y = g["ndvi"].to_numpy()
    t = g["time"].to_numpy()

    if len(g) < 6:
        return None

    base = np.nanquantile(y, q_base)
    peak_idx = int(np.nanargmax(y))
    peak_ndvi = float(y[peak_idx])
    peak_date = pd.Timestamp(t[peak_idx])

    amp = peak_ndvi - base
    if (not np.isfinite(amp)) or amp <= 0:
        return None

    T = base + frac_amp * amp
    above = y >= T
    below = y < T

    def first_consecutive(mask, start=0):
        run = 0
        for i in range(start, len(mask)):
            if mask[i]:
                run += 1
                if run >= consec:
                    return i - consec + 1
            else:
                run = 0
        return None

    sos_idx = first_consecutive(above, start=0)
    if sos_idx is None:
        return None

    eos_idx = first_consecutive(below, start=peak_idx)
    if eos_idx is None:
        eos_idx = len(g) - 1  # fallback

    sos = pd.Timestamp(t[sos_idx])
    eos = pd.Timestamp(t[eos_idx])

    if eos <= sos:
        return None

    return {
        "SOS_date": sos,
        "EOS_date": eos,
        "LOS_days": int((eos - sos).days),
        "peak_date": peak_date,
        "peak_doy": int(peak_date.dayofyear),
        "peak_ndvi": peak_ndvi,
        "SOS_doy": int(sos.dayofyear),
        "EOS_doy": int(eos.dayofyear),
        "ndvi_mean": float(np.nanmean(y)),
        "ndvi_std": float(np.nanstd(y)),
        "n_obs": int(len(g)),
        "threshold_T": float(T),
    }

# %%
rows = []
for (region, year), g in df.groupby(["NAME_1", "year"]):
    res = phenology_one_year(g)
    if res is None:
        continue
    res["NAME_1"] = region
    res["year"] = year
    rows.append(res)

pheno = pd.DataFrame(rows)
print("pheno rows:", len(pheno))
print(pheno.head())
# Out:
# pheno rows: 81
#     SOS_date   EOS_date  LOS_days  peak_date  peak_doy  peak_ndvi  SOS_doy  \
# 0 2023-01-03 2023-01-12         9 2023-01-09         9   0.814036        3
# 1 2024-01-04 2024-01-12         8 2024-01-09         9   0.815196        4
# 2 2025-01-03 2025-01-12         9 2025-01-09         9   0.805283        3
# 3 2023-01-04 2023-01-12         8 2023-01-08         8   0.730233        4
# 4 2024-01-04 2024-01-12         8 2024-01-08         8   0.729708        4
#
#    EOS_doy  ndvi_mean  ndvi_std  n_obs  threshold_T NAME_1  year
# 0       12   0.733021  0.085343     12     0.634042   Abia  2023
# 1       12   0.725422  0.089607     11     0.625407   Abia  2024
# 2       12   0.725688  0.082481     12     0.631477   Abia  2025
# 3       12   0.547411  0.164358     12     0.381178  Abuja  2023
# 4       12   0.548388  0.157401     11     0.394209  Abuja  2024

# %%
print(pheno[["SOS_doy","LOS_days","peak_doy","peak_ndvi"]].describe())
print(pheno.groupby("year")[["SOS_doy","LOS_days","peak_doy","peak_ndvi"]].describe())
print(pheno.groupby("NAME_1")[["SOS_doy","LOS_days","peak_doy","peak_ndvi"]].mean().sort_values("LOS_days"))
# Out:
#          SOS_doy   LOS_days   peak_doy  peak_ndvi
# count  81.000000  81.000000  81.000000  81.000000
# mean    4.617284   7.382716   8.222222   0.684442
# std     1.199666   1.199666   0.851469   0.090134
# min     3.000000   5.000000   6.000000   0.473400
# 25%     4.000000   6.000000   8.000000   0.620472
# 50%     4.000000   8.000000   8.000000   0.677567
# 75%     6.000000   8.000000   9.000000   0.755102
# max     7.000000   9.000000   9.000000   0.820163
#      SOS_doy                                              LOS_days            \
#        count      mean       std  min  25%  50%  75%  max    count      mean
# year
# 2023    27.0  4.333333  1.270978  3.0  3.0  4.0  6.0  6.0     27.0  7.666667
# 2024    27.0  4.888889  0.933700  4.0  4.0  5.0  6.0  6.0     27.0  7.111111
# 2025    27.0  4.629630  1.334401  3.0  3.0  5.0  6.0  7.0     27.0  7.370370
#
#       ... peak_doy      peak_ndvi                                          \
#       ...      75%  max     count      mean       std       min       25%
# year  ...
# 2023  ...      8.5  9.0      27.0  0.676681  0.102296  0.473400  0.604693
# 2024  ...      9.0  9.0      27.0  0.691951  0.084497  0.545084  0.644230
# 2025  ...      9.0  9.0      27.0  0.684694  0.085274  0.531045  0.628105
#
#
#            50%       75%       max
# year
# 2023  0.675105  0.758423  0.820163
# 2024  0.680641  0.756050  0.817077
# 2025  0.677290  0.754876  0.806758
#
# [3 rows x 32 columns]
#               SOS_doy  LOS_days  peak_doy  peak_ndvi
# NAME_1
# Yobe         6.333333  5.666667  8.000000   0.516510
# Kano         6.000000  6.000000  8.333333   0.634891
# Gombe        6.000000  6.000000  9.000000   0.563768
# Katsina      6.000000  6.000000  8.000000   0.621976
# Jigawa       6.000000  6.000000  8.000000   0.532279
# Zamfara      6.000000  6.000000  8.333333   0.669015
# Sokoto       6.000000  6.000000  8.000000   0.548470
# Kebbi        6.000000  6.000000  9.000000   0.560013
# Bauchi       5.666667  6.333333  8.333333   0.614815
# Borno        5.666667  6.333333  8.000000   0.644470
# Adamawa      5.000000  7.000000  9.000000   0.653094
# Kaduna       4.666667  7.333333  8.000000   0.711836
# Niger        4.666667  7.333333  8.666667   0.669014
# Plateau      4.666667  7.333333  8.000000   0.675298
# Taraba       4.000000  8.000000  8.000000   0.723572
# Abuja        4.000000  8.000000  8.000000   0.727833
# Kwara        4.000000  8.000000  8.666667   0.726463
# Benue        3.666667  8.333333  9.000000   0.725522
# Kogi         3.666667  8.333333  7.000000   0.757093
# Enugu        3.333333  8.666667  7.000000   0.772469
# Abia         3.333333  8.666667  9.000000   0.811505
# Edo          3.333333  8.666667  7.666667   0.814666
# Akwa Ibom    3.333333  8.666667  9.000000   0.791149
# Cross River  3.333333  8.666667  8.000000   0.807794
# Rivers       3.333333  8.666667  9.000000   0.755807
# Ogun         3.333333  8.666667  8.666667   0.791904
# Lagos        3.333333  8.666667  6.333333   0.658714

# %%
food_year = df.groupby(["NAME_1", "year"], as_index=False)["inadequate"].mean()
analysis = pheno.merge(food_year, on=["NAME_1","year"], how="inner")

print("analysis rows:", len(analysis))
print(analysis[["NAME_1","year","inadequate","LOS_days","peak_ndvi","SOS_doy","peak_doy"]].head())
# Out:
# analysis rows: 81
#   NAME_1  year  inadequate  LOS_days  peak_ndvi  SOS_doy  peak_doy
# 0   Abia  2023    0.348466         9   0.814036        3         9
# 1   Abia  2024    0.401938         8   0.815196        4         9
# 2   Abia  2025    0.204198         9   0.805283        3         9
# 3  Abuja  2023    0.275663         8   0.730233        4         8
# 4  Abuja  2024    0.329673         8   0.729708        4         8

# %%
cols = ["inadequate","SOS_doy","LOS_days","peak_doy","peak_ndvi","ndvi_mean","ndvi_std"]
corr = analysis[cols].corr(method="spearman")
print(corr)
# Out:
#             inadequate   SOS_doy  LOS_days  peak_doy  peak_ndvi  ndvi_mean  \
# inadequate    1.000000  0.726610 -0.726610 -0.007347  -0.589318  -0.658537
# SOS_doy       0.726610  1.000000 -1.000000  0.051107  -0.834834  -0.910324
# LOS_days     -0.726610 -1.000000  1.000000 -0.051107   0.834834   0.910324
# peak_doy     -0.007347  0.051107 -0.051107  1.000000   0.077885   0.083070
# peak_ndvi    -0.589318 -0.834834  0.834834  0.077885   1.000000   0.951784
# ndvi_mean    -0.658537 -0.910324  0.910324  0.083070   0.951784   1.000000
# ndvi_std      0.483266  0.486310 -0.486310 -0.072934  -0.294783  -0.472538
#
#             ndvi_std
# inadequate  0.483266
# SOS_doy     0.486310
# LOS_days   -0.486310
# peak_doy   -0.072934
# peak_ndvi  -0.294783
# ndvi_mean  -0.472538
# ndvi_std    1.000000

# %%
for y in sorted(analysis["year"].unique()):
    sub = analysis[analysis["year"]==y]
    print("\nYear:", y, "n=", len(sub))
    print(sub[cols].corr(method="spearman")["inadequate"].sort_values())
# Out:
# Year: 2023 n= 27
# LOS_days     -0.851156
# ndvi_mean    -0.805861
# peak_ndvi    -0.747863
# peak_doy      0.187770
# ndvi_std      0.435287
# SOS_doy       0.851156
# inadequate    1.000000
# Name: inadequate, dtype: float64
#
# Year: 2024 n= 27
# LOS_days     -0.851925
# ndvi_mean    -0.797314
# peak_ndvi    -0.719170
# peak_doy     -0.242202
# ndvi_std      0.582418
# SOS_doy       0.851925
# inadequate    1.000000
# Name: inadequate, dtype: float64
#
# Year: 2025 n= 27
# LOS_days     -0.684864
# ndvi_mean    -0.654457
# peak_ndvi    -0.589133
# peak_doy     -0.067596
# ndvi_std      0.558608
# SOS_doy       0.684864
# inadequate    1.000000
# Name: inadequate, dtype: float64

# %%
import matplotlib.pyplot as plt

# Choisis une région et une année à afficher
region = pheno["NAME_1"].iloc[0]
year = int(pheno.loc[pheno["NAME_1"]==region, "year"].iloc[0])

g = df[(df["NAME_1"]==region) & (df["year"]==year)].sort_values("time")
p = pheno[(pheno["NAME_1"]==region) & (pheno["year"]==year)].iloc[0]

plt.figure(figsize=(10,4))
plt.plot(g["time"], g["ndvi"], marker="o")
plt.axvline(p["SOS_date"], linestyle="--")
plt.axvline(p["EOS_date"], linestyle="--")
plt.axvline(p["peak_date"], linestyle=":")
plt.axhline(p["threshold_T"], linestyle="--")
plt.title(f"NDVI + phénologie — {region} ({year})")
plt.xlabel("Date")
plt.ylabel("NDVI")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.scatter(analysis["LOS_days"], analysis["inadequate"])
plt.title("Inadequate vs LOS")
plt.xlabel("LOS_days")
plt.ylabel("inadequate")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,5))
plt.scatter(analysis["peak_ndvi"], analysis["inadequate"])
plt.title("Inadequate vs Peak NDVI")
plt.xlabel("peak_ndvi")
plt.ylabel("inadequate")
plt.tight_layout()
plt.show()

# %%
cols = ["inadequate","SOS_doy","LOS_days","peak_doy","peak_ndvi","ndvi_mean","ndvi_std"]
corr = analysis[cols].corr(method="spearman")

plt.figure(figsize=(7,6))
plt.imshow(corr, interpolation="nearest")
plt.xticks(range(len(cols)), cols, rotation=45, ha="right")
plt.yticks(range(len(cols)), cols)
plt.colorbar()
plt.title("Corrélations Spearman")
plt.tight_layout()
plt.show()
